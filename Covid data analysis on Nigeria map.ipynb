# %% [markdown]
# ### - LET US LOAD OUR GEOJSON FILE INTO THIS NOTEBOOK USING GEOPANDAS

# %%
## Here we imported the python pandas and geoandas packages needed for working with the geojson file
import pandas as pd
import geopandas as gpd

# %%
##here we read the geojson file into the notebook as a dataframe for easy manipulations
geojson = gpd.read_file("C:\\pythonclass\\Data Science\Datasets\\Nigeral LGA map data\\Nigeria_Poly.geojson")
geojson
# Out:
#                          Name description           timestamp       id  \
# 0                        Abia        None 2019-11-05 22:59:03  3713501
# 1                     Adamawa        None 2019-12-11 22:37:02  3720358
# 2                   Akwa Ibom        None 2019-11-02 23:01:02  3715359
# 3                     Anambra        None 2019-11-03 23:02:02  3715505
# 4                      Bauchi        None 2019-11-02 23:01:02  3722233
# 5                     Bayelsa        None 2019-11-03 23:02:02  3715844
# 6                       Benue        None 2019-11-15 22:59:02  3716076
# 7                       Borno        None 2019-12-28 22:57:02  3721167
# 8                 Cross River        None 2019-12-03 22:59:01  3716250
# 9                       Delta        None 2019-10-31 23:10:02  3716950
# 10                     Ebonyi        None 2019-10-31 23:10:02  3717071
# 11                        Edo        None 2019-10-31 23:10:02  3717119
# ...

# %% [markdown]
# # SCRAPING OF DATA FROM THE NCDC SITE USING ".read_html"

# %%
data = pd.read_html("https://covid19.ncdc.gov.ng/")
data
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data = pd.read_html("https://covid19.ncdc.gov.ng/")
#       2 data
#
# File ~\anaconda3\Lib\site-packages\pandas\io\html.py:1245, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1229 if isinstance(io, str) and not any(
#    1230     [
#    1231         is_file_like(io),
#    (...)
#    1235     ]
#    1236 ):
#    1237     warnings.warn(
#    1238         "Passing literal html to 'read_html' is deprecated and "
#    1239         "will be removed in a future version. To read from a "
#    (...)
#    1242         stacklevel=find_stack_level(),
#    1243     )
# -> 1245 return _parse(
#    1246     flavor=flavor,
#    1247     io=io,
# ...
